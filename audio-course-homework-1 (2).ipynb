# %%
# !pip install pyannote.audio==2.1.1
# Out:
# Collecting pyannote.audio==2.1.1
#   Downloading pyannote.audio-2.1.1-py2.py3-none-any.whl.metadata (10 kB)
# Collecting asteroid-filterbanks<0.5,>=0.4 (from pyannote.audio==2.1.1)
#   Downloading asteroid_filterbanks-0.4.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting backports.cached-property (from pyannote.audio==2.1.1)
#   Downloading backports.cached_property-1.0.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting einops<0.4.0,>=0.3 (from pyannote.audio==2.1.1)
#   Downloading einops-0.3.2-py3-none-any.whl.metadata (10 kB)
# Collecting hmmlearn<0.3,>=0.2.7 (from pyannote.audio==2.1.1)
#   Downloading hmmlearn-0.2.8-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (2.8 kB)
# Requirement already satisfied: huggingface-hub>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==2.1.1) (0.29.0)
# Collecting networkx<3.0,>=2.6 (from pyannote.audio==2.1.1)
#   Downloading networkx-2.8.8-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: omegaconf<3.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==2.1.1) (2.3.0)
# Collecting pyannote.core<5.0,>=4.4 (from pyannote.audio==2.1.1)
#   Downloading pyannote.core-4.5-py3-none-any.whl.metadata (1.4 kB)
# Collecting pyannote.database<5.0,>=4.1.1 (from pyannote.audio==2.1.1)
#   Downloading pyannote.database-4.1.3-py3-none-any.whl.metadata (1.3 kB)
# Collecting pyannote.metrics<4.0,>=3.2 (from pyannote.audio==2.1.1)
#   Downloading pyannote.metrics-3.2.1-py3-none-any.whl.metadata (1.3 kB)
# Collecting pyannote.pipeline<3.0,>=2.3 (from pyannote.audio==2.1.1)
#   Downloading pyannote.pipeline-2.3-py3-none-any.whl.metadata (955 bytes)
# Collecting pytorch-lightning<1.7,>=1.5.4 (from pyannote.audio==2.1.1)
#   Downloading pytorch_lightning-1.6.5.post0-py3-none-any.whl.metadata (31 kB)
# Collecting pytorch-metric-learning<2.0,>=1.0.0 (from pyannote.audio==2.1.1)
#   Downloading pytorch_metric_learning-1.7.3-py3-none-any.whl.metadata (16 kB)
# Collecting semver<3.0,>=2.10.2 (from pyannote.audio==2.1.1)
#   Downloading semver-2.13.0-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting singledispatchmethod (from pyannote.audio==2.1.1)
#   Downloading singledispatchmethod-1.0-py2.py3-none-any.whl.metadata (3.6 kB)
# Collecting soundfile<0.11,>=0.10.2 (from pyannote.audio==2.1.1)
#   Downloading SoundFile-0.10.3.post1-py2.py3-none-any.whl.metadata (11 kB)
# Collecting speechbrain<0.6,>=0.5.12 (from pyannote.audio==2.1.1)
#   Downloading speechbrain-0.5.16-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==2.1.1) (2.5.1+cu121)
# Collecting torch-audiomentations>=0.11.0 (from pyannote.audio==2.1.1)
#   Downloading torch_audiomentations-0.12.0-py3-none-any.whl.metadata (15 kB)
# Collecting torchaudio<1.0,>=0.10 (from pyannote.audio==2.1.1)
#   Downloading torchaudio-0.13.1-cp310-cp310-manylinux1_x86_64.whl.metadata (1.2 kB)
# Collecting torchmetrics<1.0,>=0.6 (from pyannote.audio==2.1.1)
#   Downloading torchmetrics-0.11.4-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pyannote.audio==2.1.1) (4.12.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from asteroid-filterbanks<0.5,>=0.4->pyannote.audio==2.1.1) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.16 in /usr/local/lib/python3.10/dist-packages (from hmmlearn<0.3,>=0.2.7->pyannote.audio==2.1.1) (1.2.2)
# Requirement already satisfied: scipy>=0.19 in /usr/local/lib/python3.10/dist-packages (from hmmlearn<0.3,>=0.2.7->pyannote.audio==2.1.1) (1.13.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.1->pyannote.audio==2.1.1) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.1->pyannote.audio==2.1.1) (2024.12.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.1->pyannote.audio==2.1.1) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.1->pyannote.audio==2.1.1) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.1->pyannote.audio==2.1.1) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.1->pyannote.audio==2.1.1) (4.67.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from omegaconf<3.0,>=2.1->pyannote.audio==2.1.1) (4.9.3)
# Requirement already satisfied: sortedcontainers>=2.0.4 in /usr/local/lib/python3.10/dist-packages (from pyannote.core<5.0,>=4.4->pyannote.audio==2.1.1) (2.4.0)
# Collecting simplejson>=3.8.1 (from pyannote.core<5.0,>=4.4->pyannote.audio==2.1.1)
#   Downloading simplejson-3.20.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.10/dist-packages (from pyannote.database<5.0,>=4.1.1->pyannote.audio==2.1.1) (2.2.3)
# Requirement already satisfied: typer>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from typer[all]>=0.2.1->pyannote.database<5.0,>=4.1.1->pyannote.audio==2.1.1) (0.15.1)
# Collecting docopt>=0.6.2 (from pyannote.metrics<4.0,>=3.2->pyannote.audio==2.1.1)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from pyannote.metrics<4.0,>=3.2->pyannote.audio==2.1.1) (0.9.0)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pyannote.metrics<4.0,>=3.2->pyannote.audio==2.1.1) (3.7.5)
# Requirement already satisfied: sympy>=1.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.metrics<4.0,>=3.2->pyannote.audio==2.1.1) (1.13.1)
# Requirement already satisfied: optuna>=1.4 in /usr/local/lib/python3.10/dist-packages (from pyannote.pipeline<3.0,>=2.3->pyannote.audio==2.1.1) (4.2.1)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning<1.7,>=1.5.4->pyannote.audio==2.1.1) (2.17.1)
# Collecting pyDeprecate>=0.3.1 (from pytorch-lightning<1.7,>=1.5.4->pyannote.audio==2.1.1)
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl.metadata (10 kB)
# Collecting protobuf<=3.20.1 (from pytorch-lightning<1.7,>=1.5.4->pyannote.audio==2.1.1)
#   Downloading protobuf-3.20.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (698 bytes)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile<0.11,>=0.10.2->pyannote.audio==2.1.1) (1.17.1)
# Collecting hyperpyyaml (from speechbrain<0.6,>=0.5.12->pyannote.audio==2.1.1)
#   Downloading HyperPyYAML-1.2.2-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from speechbrain<0.6,>=0.5.12->pyannote.audio==2.1.1) (1.4.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from speechbrain<0.6,>=0.5.12->pyannote.audio==2.1.1) (0.2.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->pyannote.audio==2.1.1) (3.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy>=1.1->pyannote.metrics<4.0,>=3.2->pyannote.audio==2.1.1) (1.3.0)
# Collecting julius<0.3,>=0.2.3 (from torch-audiomentations>=0.11.0->pyannote.audio==2.1.1)
#   Downloading julius-0.2.7.tar.gz (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 3.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting torch-pitch-shift>=1.2.2 (from torch-audiomentations>=0.11.0->pyannote.audio==2.1.1)
#   Downloading torch_pitch_shift-1.2.5-py3-none-any.whl.metadata (2.5 kB)
# Collecting torch>=1.9 (from pyannote.audio==2.1.1)
#   Downloading torch-1.13.1-cp310-cp310-manylinux1_x86_64.whl.metadata (24 kB)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch>=1.9->pyannote.audio==2.1.1)
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch>=1.9->pyannote.audio==2.1.1)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch>=1.9->pyannote.audio==2.1.1)
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch>=1.9->pyannote.audio==2.1.1)
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.9->pyannote.audio==2.1.1) (75.1.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.9->pyannote.audio==2.1.1) (0.45.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile<0.11,>=0.10.2->pyannote.audio==2.1.1) (2.22)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio==2.1.1) (3.11.12)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics<4.0,>=3.2->pyannote.audio==2.1.1) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics<4.0,>=3.2->pyannote.audio==2.1.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics<4.0,>=3.2->pyannote.audio==2.1.1) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics<4.0,>=3.2->pyannote.audio==2.1.1) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics<4.0,>=3.2->pyannote.audio==2.1.1) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics<4.0,>=3.2->pyannote.audio==2.1.1) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pyannote.metrics<4.0,>=3.2->pyannote.audio==2.1.1) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy->asteroid-filterbanks<0.5,>=0.4->pyannote.audio==2.1.1) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy->asteroid-filterbanks<0.5,>=0.4->pyannote.audio==2.1.1) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy->asteroid-filterbanks<0.5,>=0.4->pyannote.audio==2.1.1) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy->asteroid-filterbanks<0.5,>=0.4->pyannote.audio==2.1.1) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy->asteroid-filterbanks<0.5,>=0.4->pyannote.audio==2.1.1) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy->asteroid-filterbanks<0.5,>=0.4->pyannote.audio==2.1.1) (2.4.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna>=1.4->pyannote.pipeline<3.0,>=2.3->pyannote.audio==2.1.1) (1.14.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna>=1.4->pyannote.pipeline<3.0,>=2.3->pyannote.audio==2.1.1) (6.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from optuna>=1.4->pyannote.pipeline<3.0,>=2.3->pyannote.audio==2.1.1) (2.0.36)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pyannote.database<5.0,>=4.1.1->pyannote.audio==2.1.1) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pyannote.database<5.0,>=4.1.1->pyannote.audio==2.1.1) (2025.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.16->hmmlearn<0.3,>=0.2.7->pyannote.audio==2.1.1) (3.5.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio==2.1.1) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio==2.1.1) (1.68.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio==2.1.1) (3.7)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio==2.1.1) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio==2.1.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio==2.1.1) (3.1.3)
# Collecting primePy>=1.3 (from torch-pitch-shift>=1.2.2->torch-audiomentations>=0.11.0->pyannote.audio==2.1.1)
#   Downloading primePy-1.3-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.2.1->typer[all]>=0.2.1->pyannote.database<5.0,>=4.1.1->pyannote.audio==2.1.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.2.1->typer[all]>=0.2.1->pyannote.database<5.0,>=4.1.1->pyannote.audio==2.1.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.2.1->typer[all]>=0.2.1->pyannote.database<5.0,>=4.1.1->pyannote.audio==2.1.1) (13.9.4)
# WARNING: typer 0.15.1 does not provide the extra 'all'
# Collecting ruamel.yaml>=0.17.28 (from hyperpyyaml->speechbrain<0.6,>=0.5.12->pyannote.audio==2.1.1)
#   Downloading ruamel.yaml-0.18.10-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.1->pyannote.audio==2.1.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.1->pyannote.audio==2.1.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.1->pyannote.audio==2.1.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.1->pyannote.audio==2.1.1) (2025.1.31)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio==2.1.1) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio==2.1.1) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio==2.1.1) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio==2.1.1) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio==2.1.1) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio==2.1.1) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio==2.1.1) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio==2.1.1) (1.18.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna>=1.4->pyannote.pipeline<3.0,>=2.3->pyannote.audio==2.1.1) (1.3.9)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.2.1->typer[all]>=0.2.1->pyannote.database<5.0,>=4.1.1->pyannote.audio==2.1.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.2.1->typer[all]>=0.2.1->pyannote.database<5.0,>=4.1.1->pyannote.audio==2.1.1) (2.19.1)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.28->hyperpyyaml->speechbrain<0.6,>=0.5.12->pyannote.audio==2.1.1)
#   Downloading ruamel.yaml.clib-0.2.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.4.2->optuna>=1.4->pyannote.pipeline<3.0,>=2.3->pyannote.audio==2.1.1) (3.1.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.2.0->pytorch-lightning<1.7,>=1.5.4->pyannote.audio==2.1.1) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->asteroid-filterbanks<0.5,>=0.4->pyannote.audio==2.1.1) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->asteroid-filterbanks<0.5,>=0.4->pyannote.audio==2.1.1) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy->asteroid-filterbanks<0.5,>=0.4->pyannote.audio==2.1.1) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy->asteroid-filterbanks<0.5,>=0.4->pyannote.audio==2.1.1) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy->asteroid-filterbanks<0.5,>=0.4->pyannote.audio==2.1.1) (2024.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.2.1->typer[all]>=0.2.1->pyannote.database<5.0,>=4.1.1->pyannote.audio==2.1.1) (0.1.2)
# Downloading pyannote.audio-2.1.1-py2.py3-none-any.whl (390 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.7/390.7 kB 15.8 MB/s eta 0:00:00
# Downloading asteroid_filterbanks-0.4.0-py3-none-any.whl (29 kB)
# Downloading einops-0.3.2-py3-none-any.whl (25 kB)
# Downloading hmmlearn-0.2.8-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.whl (217 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.2/217.2 kB 9.2 MB/s eta 0:00:00
# Downloading networkx-2.8.8-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 49.1 MB/s eta 0:00:00:00:01
# Downloading pyannote.core-4.5-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.5/60.5 kB 2.6 MB/s eta 0:00:00
# Downloading pyannote.database-4.1.3-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 kB 2.0 MB/s eta 0:00:00
# Downloading pyannote.metrics-3.2.1-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 2.4 MB/s eta 0:00:00
# Downloading pyannote.pipeline-2.3-py3-none-any.whl (30 kB)
# Downloading pytorch_lightning-1.6.5.post0-py3-none-any.whl (585 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 585.9/585.9 kB 24.8 MB/s eta 0:00:00
# Downloading pytorch_metric_learning-1.7.3-py3-none-any.whl (112 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 5.4 MB/s eta 0:00:00
# Downloading semver-2.13.0-py2.py3-none-any.whl (12 kB)
# Downloading SoundFile-0.10.3.post1-py2.py3-none-any.whl (21 kB)
# Downloading speechbrain-0.5.16-py3-none-any.whl (630 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 630.6/630.6 kB 22.1 MB/s eta 0:00:00
# Downloading torch_audiomentations-0.12.0-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 2.2 MB/s eta 0:00:00
# Downloading torchaudio-0.13.1-cp310-cp310-manylinux1_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 68.2 MB/s eta 0:00:00:00:01
# Downloading torch-1.13.1-cp310-cp310-manylinux1_x86_64.whl (887.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 1.6 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 2.6 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 60.7 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 32.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.3 MB/s eta 0:00:000:00:0100:01
# Downloading torchmetrics-0.11.4-py3-none-any.whl (519 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 kB 18.9 MB/s eta 0:00:00
# Downloading backports.cached_property-1.0.2-py3-none-any.whl (6.1 kB)
# Downloading singledispatchmethod-1.0-py2.py3-none-any.whl (4.7 kB)
# Downloading protobuf-3.20.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 31.1 MB/s eta 0:00:00:00:01
# Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Downloading simplejson-3.20.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.0/138.0 kB 6.6 MB/s eta 0:00:00
# Downloading torch_pitch_shift-1.2.5-py3-none-any.whl (5.0 kB)
# Downloading HyperPyYAML-1.2.2-py3-none-any.whl (16 kB)
# Downloading primePy-1.3-py3-none-any.whl (4.0 kB)
# Downloading ruamel.yaml-0.18.10-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 5.1 MB/s eta 0:00:00
# Downloading ruamel.yaml.clib-0.2.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (722 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 722.2/722.2 kB 25.9 MB/s eta 0:00:00
# Building wheels for collected packages: docopt, julius
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=42166902896e8081f6105f0467ba5a43eeea4e34cbfa5778dc44a77869f205d7
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
#   Building wheel for julius (setup.py) ... done
#   Created wheel for julius: filename=julius-0.2.7-py3-none-any.whl size=21869 sha256=b17fcb9cc4481f2dabea339025617e11d50efabf91e983b43048f48bfabf7a4a
#   Stored in directory: /root/.cache/pip/wheels/b9/b2/05/f883527ffcb7f2ead5438a2c23439aa0c881eaa9a4c80256f4
# Successfully built docopt julius
# Installing collected packages: singledispatchmethod, primePy, einops, docopt, simplejson, semver, ruamel.yaml.clib, pyDeprecate, protobuf, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, networkx, backports.cached-property, soundfile, ruamel.yaml, nvidia-cudnn-cu11, torch, hyperpyyaml, torchaudio, julius, torch-pitch-shift, torch-audiomentations, pyannote.core, torchmetrics, pyannote.database, speechbrain, pytorch-metric-learning, pytorch-lightning, pyannote.pipeline, pyannote.metrics, hmmlearn, asteroid-filterbanks, pyannote.audio
#   Attempting uninstall: einops
#     Found existing installation: einops 0.8.0
#     Uninstalling einops-0.8.0:
#       Successfully uninstalled einops-0.8.0
#   Attempting uninstall: semver
#     Found existing installation: semver 3.0.4
#     Uninstalling semver-3.0.4:
#       Successfully uninstalled semver-3.0.4
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.4.2
#     Uninstalling networkx-3.4.2:
#       Successfully uninstalled networkx-3.4.2
#   Attempting uninstall: soundfile
#     Found existing installation: soundfile 0.12.1
#     Uninstalling soundfile-0.12.1:
#       Successfully uninstalled soundfile-0.12.1
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1+cu121
#     Uninstalling torch-2.5.1+cu121:
#       Successfully uninstalled torch-2.5.1+cu121
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.5.1+cu121
#     Uninstalling torchaudio-2.5.1+cu121:
#       Successfully uninstalled torchaudio-2.5.1+cu121
#   Attempting uninstall: torchmetrics
#     Found existing installation: torchmetrics 1.6.1
#     Uninstalling torchmetrics-1.6.1:
#       Successfully uninstalled torchmetrics-1.6.1
#   Attempting uninstall: pytorch-lightning
#     Found existing installation: pytorch-lightning 2.5.0.post0
#     Uninstalling pytorch-lightning-2.5.0.post0:
#       Successfully uninstalled pytorch-lightning-2.5.0.post0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-ai-generativelanguage 0.6.10 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.20.1 which is incompatible.
# google-api-core 1.34.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<4.0.0dev,>=3.19.5, but you have protobuf 3.20.1 which is incompatible.
# google-cloud-aiplatform 1.74.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.20.1 which is incompatible.
# google-cloud-bigquery-connection 1.17.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.20.1 which is incompatible.
# google-cloud-bigtable 2.27.0 requires google-api-core[grpc]<3.0.0dev,>=2.16.0, but you have google-api-core 1.34.1 which is incompatible.
# google-cloud-bigtable 2.27.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.20.1 which is incompatible.
# google-cloud-datastore 2.20.2 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.20.1 which is incompatible.
# google-cloud-firestore 2.19.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.20.1 which is incompatible.
# google-cloud-functions 1.19.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.20.1 which is incompatible.
# google-cloud-iam 2.17.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.20.1 which is incompatible.
# google-cloud-language 2.16.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.20.1 which is incompatible.
# google-cloud-pubsub 2.27.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.20.1 which is incompatible.
# google-cloud-resource-manager 1.14.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.20.1 which is incompatible.
# google-cloud-translate 3.12.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.20.1 which is incompatible.
# google-cloud-videointelligence 2.16.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.20.1 which is incompatible.
# google-cloud-vision 3.10.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.20.1 which is incompatible.
# googleapis-common-protos 1.66.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.20.2, but you have protobuf 3.20.1 which is incompatible.
# grpc-google-iam-v1 0.13.1 requires protobuf!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.20.1 which is incompatible.
# librosa 0.10.2.post1 requires soundfile>=0.12.1, but you have soundfile 0.10.3.post1 which is incompatible.
# nx-cugraph-cu12 24.10.0 requires networkx>=3.0, but you have networkx 2.8.8 which is incompatible.
# onnx 1.17.0 requires protobuf>=3.20.2, but you have protobuf 3.20.1 which is incompatible.
# pandas-gbq 0.25.0 requires google-api-core<3.0.0dev,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# scikit-image 0.25.0 requires networkx>=3.0, but you have networkx 2.8.8 which is incompatible.
# tensorflow 2.17.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.20.1 which is incompatible.
# tensorflow-decision-forests 1.10.0 requires tensorflow==2.17.0, but you have tensorflow 2.17.1 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 3.20.1 which is incompatible.
# torchvision 0.20.1+cu121 requires torch==2.5.1, but you have torch 1.13.1 which is incompatible.
# Successfully installed asteroid-filterbanks-0.4.0 backports.cached-property-1.0.2 docopt-0.6.2 einops-0.3.2 hmmlearn-0.2.8 hyperpyyaml-1.2.2 julius-0.2.7 networkx-2.8.8 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 primePy-1.3 protobuf-3.20.1 pyDeprecate-0.3.2 pyannote.audio-2.1.1 pyannote.core-4.5 pyannote.database-4.1.3 pyannote.metrics-3.2.1 pyannote.pipeline-2.3 pytorch-lightning-1.6.5.post0 pytorch-metric-learning-1.7.3 ruamel.yaml-0.18.10 ruamel.yaml.clib-0.2.12 semver-2.13.0 simplejson-3.20.1 singledispatchmethod-1.0 soundfile-0.10.3.post1 speechbrain-0.5.16 torch-1.13.1 torch-audiomentations-0.12.0 torch-pitch-shift-1.2.5 torchaudio-0.13.1 torchmetrics-0.11.4

# %%
import os
import numpy as np
import librosa
import torch
from sklearn.cluster import KMeans
from pyannote.core import Annotation, Segment
from pyannote.metrics.detection import DetectionErrorRate

# %%
BASE_DIR  = '/kaggle/input/english-multispeaker-corpus-for-voice-cloning/VCTK-Corpus/VCTK-Corpus'
TXT_DIR =  os.path.join(BASE_DIR, 'txt')
AUDIO_DIR = os.path.join(BASE_DIR, 'wav48')

SAMPLING_RATE = 22050
MAX_DURATION = 8
SR_DOWNSAMPLE = 2

# %%
speaker_ids = sorted(os.listdir(TXT_DIR))
print('number of speakers is', len(speaker_ids))
# Out:
# number of speakers is 108

# %%
def get_speech(speaker_id = np.random.choice(speaker_ids), passage_id = None):
    if not passage_id:
        speaker_passage_path = os.path.join(TXT_DIR, speaker_id)
        passage_id = np.random.choice(os.listdir(speaker_passage_path))[:-4]
        
    text_path = os.path.join(TXT_DIR, speaker_id, passage_id + '.txt')
    speech_path = os.path.join(AUDIO_DIR, speaker_id, passage_id + '.wav')
    
    x, sr = librosa.load(speech_path)
    
    with open(text_path, 'r') as text_file:
        text = text_file.read()
        
    return x, sr, text, speech_path
        
        
x, sr, text, speech_path = get_speech()
print('sampling rate', sr, 'hz')
print('number of samples', len(x))
print('duration', round(len(x)/sr, 2), 'seconds')
# Out:
# sampling rate 22050 hz
# number of samples 64070
# duration 2.91 seconds

# %%
import IPython.display as ipd
print(text)
ipd.Audio(speech_path)
# Out:
# Donald was his friend.
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave_paths = []
for root, dirs, files in os.walk(BASE_DIR):
    for file in files:
        if file.endswith('.wav'):
            wave_paths.append(os.path.join(root, file))

# %%
wave_paths = wave_paths[:1000]

# %%
def post_process_vad_labels(vad_labels, min_duration_frames=3, merge_gap_frames=2):
    """
    Удаляет слишком короткие речевые сегменты и объединяет соседние сегменты,
    если разрыв между ними менее merge_gap_frames.
    """
    processed = vad_labels.copy()
    n = len(processed)
    
    start = None
    for i in range(n):
        if processed[i] == 1 and start is None:
            start = i
        elif processed[i] == 0 and start is not None:
            if (i - start) < min_duration_frames:
                processed[start:i] = 0
            start = None
    if start is not None and (n - start) < min_duration_frames:
        processed[start:] = 0

    i = 1
    while i < n:
        if processed[i-1] == 1 and processed[i] == 0:
            gap_start = i
            while i < n and processed[i] == 0:
                i += 1
            gap_length = i - gap_start
            if gap_length <= merge_gap_frames:
                processed[gap_start:i] = 1
        else:
            i += 1

    return processed

def frames_to_annotation(vad_labels, sr, hop_length):
    vad_labels = post_process_vad_labels(vad_labels)
    
    annotation = Annotation()
    in_speech = False
    start_time = None
    frame_duration = hop_length / sr
    for i, label in enumerate(vad_labels):
        t = i * frame_duration
        if label == 1 and not in_speech:
            in_speech = True
            start_time = t
        elif label == 0 and in_speech:
            end_time = t
            annotation[Segment(start_time, end_time)] = "SPEECH"
            in_speech = False
    if in_speech:
        end_time = len(vad_labels) * frame_duration
        annotation[Segment(start_time, end_time)] = "SPEECH"
    return annotation

# %% [markdown]
# ### Energy only approach

# %%
def energy_vad(audio, sr, frame_length=1024, hop_length=512, energy_threshold=0.1):
    frames = librosa.util.frame(audio, frame_length=frame_length, hop_length=hop_length).T
    energies = np.sum(frames**2, axis=1)

    norm_energy = energies / (np.max(energies) + 1e-8)
    vad_labels = (norm_energy > energy_threshold).astype(int)
    return vad_labels

# %% [markdown]
# ### ZCR (scaled) and Spectral Centroid (scaled)

# %%
def zcr_spec_vad(audio, sr, frame_length=1024, hop_length=512):
    zcr = librosa.feature.zero_crossing_rate(y=audio, frame_length=frame_length, 
                                               hop_length=hop_length, center=False)[0]
    spec_centroid = librosa.feature.spectral_centroid(y=audio, sr=sr, n_fft=frame_length, 
                                                      hop_length=hop_length, center=False)[0]
    
    frames = librosa.util.frame(audio, frame_length=frame_length, hop_length=hop_length).T
    energies = np.sum(frames**2, axis=1)
    
    min_frames = min(len(zcr), len(energies), len(spec_centroid))
    zcr = zcr[:min_frames]
    spec_centroid = spec_centroid[:min_frames]
    energies = energies[:min_frames]
    
    features = np.vstack([zcr, spec_centroid]).T
    features = (features - np.mean(features, axis=0)) / (np.std(features, axis=0) + 1e-8)
    
    kmeans = KMeans(n_clusters=2, random_state=0).fit(features)
    labels = kmeans.labels_
    
    cluster0_energy = np.mean(energies[labels == 0]) if np.any(labels == 0) else 0
    cluster1_energy = np.mean(energies[labels == 1]) if np.any(labels == 1) else 0
    speech_cluster = 0 if cluster0_energy > cluster1_energy else 1
    vad_labels = (labels == speech_cluster).astype(int)
    return vad_labels

# %% [markdown]
# ### MFCC

# %%
def mfcc_vad(audio, sr, frame_length=1024, hop_length=512, n_mfcc=13):
    mfcc = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=n_mfcc,
                                n_fft=frame_length, hop_length=hop_length, center=False)
    mfcc = mfcc.T  
    
    frames = librosa.util.frame(audio, frame_length=frame_length, hop_length=hop_length).T
    energies = np.sum(frames**2, axis=1)
    
    min_frames = min(mfcc.shape[0], len(energies))
    mfcc = mfcc[:min_frames, :]
    energies = energies[:min_frames]
    
    features = (mfcc - np.mean(mfcc, axis=0)) / (np.std(mfcc, axis=0) + 1e-8)
    
    kmeans = KMeans(n_clusters=2, random_state=0).fit(features)
    labels = kmeans.labels_
    
    cluster0_energy = np.mean(energies[labels == 0]) if np.any(labels == 0) else 0
    cluster1_energy = np.mean(energies[labels == 1]) if np.any(labels == 1) else 0
    speech_cluster = 0 if cluster0_energy > cluster1_energy else 1
    vad_labels = (labels == speech_cluster).astype(int)
    
    return vad_labels

# %% [markdown]
# ### All features together (Energy, ZCR, Spectral Centroid, MFCC)

# %%
def all_features_vad(audio, sr, frame_length=1024, hop_length=512, n_mfcc=13):
    frames = librosa.util.frame(audio, frame_length=frame_length, hop_length=hop_length).T
    energies = np.sum(frames**2, axis=1)
    
    zcr = librosa.feature.zero_crossing_rate(y=audio, frame_length=frame_length, 
                                               hop_length=hop_length, center=False)[0]
    spec_centroid = librosa.feature.spectral_centroid(y=audio, sr=sr, n_fft=frame_length, 
                                                      hop_length=hop_length, center=False)[0]
    mfcc = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=n_mfcc, n_fft=frame_length, 
                                hop_length=hop_length, center=False)
    mfcc = mfcc.T  
    
    min_frames = min(len(energies), len(zcr), len(spec_centroid), mfcc.shape[0])
    energies = energies[:min_frames]
    zcr = zcr[:min_frames]
    spec_centroid = spec_centroid[:min_frames]
    mfcc = mfcc[:min_frames, :]
    
    features = np.column_stack([energies, zcr, spec_centroid, mfcc])
    features = (features - np.mean(features, axis=0)) / (np.std(features, axis=0) + 1e-8)
    
    kmeans = KMeans(n_clusters=2, random_state=0).fit(features)
    labels = kmeans.labels_
    
    cluster0_energy = np.mean(energies[labels == 0]) if np.any(labels == 0) else 0
    cluster1_energy = np.mean(energies[labels == 1]) if np.any(labels == 1) else 0
    speech_cluster = 0 if cluster0_energy > cluster1_energy else 1
    vad_labels = (labels == speech_cluster).astype(int)
    return vad_labels

# %%
# Silero VAD for reference
model, utils = torch.hub.load('snakers4/silero-vad', 'silero_vad', force_reload=True)
(get_speech_timestamps, _, read_audio, _, _) = utils
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/hub.py:267: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/snakers4/silero-vad/zipball/master" to /root/.cache/torch/hub/master.zip

# %%
metric_energy = DetectionErrorRate()
metric_zcr_spec = DetectionErrorRate()
metric_mfcc = DetectionErrorRate()
metric_all = DetectionErrorRate()

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", message=".*uem was approximated by the union.*")

# %% [markdown]
# ### Main cycle

# %%
for file in wave_paths:
    
    audio, sr = librosa.load(file, sr=None)
    
    # Silero VAD 
    speech_timestamps = get_speech_timestamps(audio, model, sampling_rate=sr)
    reference = Annotation()
    for speech in speech_timestamps:
        reference[Segment(speech["start"] / sr, speech["end"] / sr)] = "SPEECH"
    
    # Method 1 
    vad_labels_energy = energy_vad(audio, sr)
    hypothesis_energy = frames_to_annotation(vad_labels_energy, sr, hop_length=512)
    _ = metric_energy(reference, hypothesis_energy)
    
    # Method 2 
    vad_labels_zcr_spec = zcr_spec_vad(audio, sr)
    hypothesis_zcr_spec = frames_to_annotation(vad_labels_zcr_spec, sr, hop_length=512)
    _ = metric_zcr_spec(reference, hypothesis_zcr_spec)
    
    # Method 3 
    vad_labels_mfcc = mfcc_vad(audio, sr)
    hypothesis_mfcc = frames_to_annotation(vad_labels_mfcc, sr, hop_length=512)
    _ = metric_mfcc(reference, hypothesis_mfcc)
    
    # Method 4 
    vad_labels_all = all_features_vad(audio, sr)
    hypothesis_all = frames_to_annotation(vad_labels_all, sr, hop_length=512)
    _ = metric_all(reference, hypothesis_all)

# %% [markdown]
# ### Detection Error Rate

# %%
der_energy = abs(metric_energy)
der_zcr_spec = abs(metric_zcr_spec)
der_mfcc = abs(metric_mfcc)
der_all = abs(metric_all)

print(f'Method 1 (Energy only): Detection error rate = {der_energy * 100:.1f}%')
print(f'Method 2 (ZCR + Spectral Centroid): Detection error rate = {der_zcr_spec * 100:.1f}%')
print(f'Method 3 (MFCC only): Detection error rate = {der_mfcc * 100:.1f}%')
print(f'Method 4 (All features): Detection error rate = {der_all * 100:.1f}%')
# Out:
# Method 1 (Energy only): Detection error rate = 58.8%
# Method 2 (ZCR + Spectral Centroid): Detection error rate = 77.1%
# Method 3 (MFCC only): Detection error rate = 33.1%
# Method 4 (All features): Detection error rate = 36.2%

# %% [markdown]
# Mabye mistake or misuderstanding in Method 2, cause results are wort than i expected
#
# MFCC surprisingly good, idea from https://wiki.aalto.fi/display/ITSP/Cepstrum+and+MFCC and https://wiki.aalto.fi/pages/viewpage.action?pageId=151500905 worked. Very helpful links for my research

# %%
def visualize_segmentation(audio, sr, reference, hypothesis, title="Segmentation Comparison"):
    t = np.linspace(0, len(audio)/sr, num=len(audio))
    plt.figure(figsize=(14, 6))
    plt.plot(t, audio, color="gray", alpha=0.6, label="Waveform")
    
    for segment in reference.itersegments():
        plt.axvspan(segment.start, segment.end, color="green", alpha=0.3, label="Reference")
    
    for segment in hypothesis.itersegments():
        plt.axvspan(segment.start, segment.end, color="red", alpha=0.3, label="Hypothesis")
    
    handles, labels = plt.gca().get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    plt.legend(by_label.values(), by_label.keys())
    
    plt.xlabel("Time (s)")
    plt.title(title)
    plt.show()

# %% [markdown]
# ### Example on a single file

# %%
import matplotlib.pyplot as plt

audio_path = speech_path
audio, sr = librosa.load(audio_path, sr=None)
print(sr)
speech_timestamps = get_speech_timestamps(audio, model, sampling_rate=sr)
reference = Annotation()
for speech in speech_timestamps:
    reference[Segment(speech["start"]/sr, speech["end"]/sr)] = "SPEECH"

vad_labels = all_features_vad(audio, sr, frame_length=1024, hop_length=512, n_mfcc=13)
hypothesis = frames_to_annotation(vad_labels, sr, hop_length=512)

visualize_segmentation(audio, sr, reference, hypothesis, title="Reference (Green) vs. Hypothesis (Red)")
# Out:
# 48000
